# %% [markdown]
# <a href="https://colab.research.google.com/github/andresec20/genji/blob/master/CLASE_10F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
import os
path = '/content/drive/My Drive/7/Procesamiento Imagenes/'
os.chdir(path)
# !pwd
# Out:
# /content/drive/My Drive/7/Procesamiento Imagenes

# %%
img_BGR = cv2.imread('Ima.jpg',cv2.COLOR_BGR2RGB )
plt.imshow(img_BGR)
plt.show()

# %%
# dsipaly para dos imagenes
def display (a,b, title1 = "Original", title2 = "Edited"):
  plt.figure(figsize=(14,14))
  plt.subplot(121),plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()



  #display de una imagen
  def display_one(a, title1 = "original"):
    plt.imshow(a), plt.title(title1)
    plt.show()
  
  display_one(img_BGR)

# %%
def display (a,b,,c,d title1 = "Original", title2 = "Edited", title3 = "edited2", title4 = "Edited3"):
  plt.figure(figsize=(14,14))
  plt.subplot(221),plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(222), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(223),plt.imshow(c), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.subplot(224), plt.imshow(d,cmap = 'gray'), plt.title(title4)
  plt.xticks([]), plt.yticks([])
  plt.show()

display4(img_BGR,img_RGB,img_GRAY,"BRG","RGB","GRAY","GRAY")

# %%
def estadisticas(img_BGR):

    img_size = img.shape

    if len(img_size)>2:
      print("image chanels",img_sixe[2])
    else:
      print("image chanels",1)

    print("image W", img_size[1])
    print("image H", img_size[0])
    print("min value", img.max())
    print("prom",img.mean())
    print("type",img.dtype)

# %%
images = []
IMAGE_DIRECTORY = '/content/drive/My drive/7/Procesamiento Imagenes/'

def get_image(image_path):
    image = cv.imread(image_path)
    image = cv2.cvtcolor(image, cv2.COLOR_BGR2RGB)
    return image

for file in os.listdir(IMAGE_DIRECTORY):
    if not file.startswith('.'):
        images.append(get_image(os.path.join(IMAGE_DIRECTORY, file)))


plt.figure(figsize=(20,10))
for i in range(len(images)):
    plt.subplot(1, len(images))
    plt.imshow(image[i])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-55e247fee6d7> in <module>()
#       7     return image
#       8
# ----> 9 for file in os.listdir(IMAGE_DIRECTORY):
#      10     if not file.startswith('.'):
#      11         images.append(get_image(os.path.join(IMAGE_DIRECTORY, file)))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My drive/7/Procesamiento Imagenes/'
